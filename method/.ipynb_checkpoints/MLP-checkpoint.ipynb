# %%
import os, torch
import numpy as np
import pandas as pd
from torch import nn
import torch.nn.functional as F
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
from dataPre import *
# Out:
# >> Pathway Data : KEGG
# pathway matrix shape :  torch.Size([184, 20493])
# num_pathway :  184
# >> Methylation Data: gene.average.beta.by.intensity.csv
# sample_dim :  194
# input_size (number of genes):  20493
# patient list :  ['methylated-15-07-006-9', 'methylated-15-04-005-6', 'methylated-15-02-021-8', 'methylated-15-05-030-6', 'methylated-15-08-032-9', 'methylated-15-05-019-0']
# feature list :  ['TSPY4', 'TTTY14', 'TMSB4Y', 'TBL1Y', 'RPS4Y2', 'EIF1AY']

# %%
trainArgs = {}
trainArgs['x_data'] = expression
trainArgs['y_data'] = status
trainArgs['pathway_info'] = pathway_info
# trainArgs['num_fc_list'] = [32, 64, 128]
# trainArgs['lr_list'] = [0.0001,0.0005,0.001]
trainArgs['num_fc_list'] = [128]
trainArgs['lr_list'] = [0.0005]
trainArgs['device'] = '0'
trainArgs['seed'] = 0
trainArgs['pathway'] = pathway
trainArgs['tissue'] = tissue
trainArgs['filename'] = 'result_mlp.csv'

# %%
from train import *
# Out:
# Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)

# %%
train = train_kfold_mlp(trainArgs)

# %%
result = train.kfold_mlp()
# Out:
# ****************************************************************************
# Fold 1 / 10
# ****************************************************************************
# Validation AUC increased (0.000000 --> 0.550000).  Saving model ...
# Validation AUC increased (0.550000 --> 0.610000).  Saving model ...
# Validation AUC increased (0.610000 --> 0.620000).  Saving model ...
# Validation AUC increased (0.620000 --> 0.630000).  Saving model ...
# ****************************************************************************
# Fold 2 / 10
# ****************************************************************************
# Validation AUC increased (0.000000 --> 0.580000).  Saving model ...
# Validation AUC increased (0.580000 --> 0.620000).  Saving model ...
# Validation AUC increased (0.620000 --> 0.640000).  Saving model ...
# Validation AUC increased (0.640000 --> 0.650000).  Saving model ...
# Validation AUC increased (0.650000 --> 0.730000).  Saving model ...
# Validation AUC increased (0.730000 --> 0.790000).  Saving model ...
# ****************************************************************************
# Fold 3 / 10
# ****************************************************************************
# Validation AUC increased (0.000000 --> 0.390000).  Saving model ...
# Validation AUC increased (0.390000 --> 0.440000).  Saving model ...
# Validation AUC increased (0.440000 --> 0.450000).  Saving model ...
# Validation AUC increased (0.450000 --> 0.530000).  Saving model ...
# Validation AUC increased (0.530000 --> 0.540000).  Saving model ...
# Validation AUC increased (0.540000 --> 0.610000).  Saving model ...
# Validation AUC increased (0.610000 --> 0.650000).  Saving model ...
# Validation AUC increased (0.650000 --> 0.670000).  Saving model ...
# Validation AUC increased (0.670000 --> 0.700000).  Saving model ...
# Validation AUC increased (0.700000 --> 0.730000).  Saving model ...
# ****************************************************************************
# Fold 4 / 10
# ****************************************************************************
# Validation AUC increased (0.000000 --> 0.490000).  Saving model ...
# Validation AUC increased (0.490000 --> 0.500000).  Saving model ...
# Validation AUC increased (0.500000 --> 0.510000).  Saving model ...
# Validation AUC increased (0.510000 --> 0.530000).  Saving model ...
# Validation AUC increased (0.530000 --> 0.560000).  Saving model ...
# Validation AUC increased (0.560000 --> 0.570000).  Saving model ...
# Validation AUC increased (0.570000 --> 0.600000).  Saving model ...
# ****************************************************************************
# Fold 5 / 10
# ****************************************************************************
# Validation AUC increased (0.000000 --> 0.450000).  Saving model ...
# Validation AUC increased (0.450000 --> 0.480000).  Saving model ...
# Validation AUC increased (0.480000 --> 0.490000).  Saving model ...
# Validation AUC increased (0.490000 --> 0.510000).  Saving model ...
# Validation AUC increased (0.510000 --> 0.520000).  Saving model ...
# ****************************************************************************
# Fold 6 / 10
# ****************************************************************************
# Validation AUC increased (0.000000 --> 0.530000).  Saving model ...
# Validation AUC increased (0.530000 --> 0.570000).  Saving model ...
# Validation AUC increased (0.570000 --> 0.650000).  Saving model ...
# Validation AUC increased (0.650000 --> 0.680000).  Saving model ...
# Validation AUC increased (0.680000 --> 0.710000).  Saving model ...
# Validation AUC increased (0.710000 --> 0.730000).  Saving model ...
# ****************************************************************************
# Fold 7 / 10
# ****************************************************************************
# Validation AUC increased (0.000000 --> 0.480000).  Saving model ...
# Validation AUC increased (0.480000 --> 0.490000).  Saving model ...
# Validation AUC increased (0.490000 --> 0.530000).  Saving model ...
# Validation AUC increased (0.530000 --> 0.590000).  Saving model ...
# ****************************************************************************
# Fold 8 / 10
# ****************************************************************************
# Validation AUC increased (0.000000 --> 0.560000).  Saving model ...
# Validation AUC increased (0.560000 --> 0.670000).  Saving model ...
# Validation AUC increased (0.670000 --> 0.690000).  Saving model ...
# Validation AUC increased (0.690000 --> 0.710000).  Saving model ...
# Validation AUC increased (0.710000 --> 0.720000).  Saving model ...
# Validation AUC increased (0.720000 --> 0.730000).  Saving model ...
# ****************************************************************************
# Fold 9 / 10
# ****************************************************************************
# Validation AUC increased (0.000000 --> 0.350000).  Saving model ...
# Validation AUC increased (0.350000 --> 0.390000).  Saving model ...
# Validation AUC increased (0.390000 --> 0.450000).  Saving model ...
# Validation AUC increased (0.450000 --> 0.470000).  Saving model ...
# Validation AUC increased (0.470000 --> 0.490000).  Saving model ...
# Validation AUC increased (0.490000 --> 0.500000).  Saving model ...
# Validation AUC increased (0.500000 --> 0.520000).  Saving model ...
# Validation AUC increased (0.520000 --> 0.570000).  Saving model ...
# ****************************************************************************
# Fold 10 / 10
# ****************************************************************************
# Validation AUC increased (0.000000 --> 0.470000).  Saving model ...
# Validation AUC increased (0.470000 --> 0.560000).  Saving model ...

# %%
result
# Out:
#                hyperparam Fold  Valid_AUC  Valid_Precision  Valid_Recall  \
# 0  lr:0.0005 / num_fc:128    0       0.63         0.555556           1.0
# 1  lr:0.0005 / num_fc:128    1       0.79         0.625000           1.0
# 2  lr:0.0005 / num_fc:128    2       0.73         0.777778           0.7
# 3  lr:0.0005 / num_fc:128    3       0.60         0.562500           0.9
# 4  lr:0.0005 / num_fc:128    4       0.52         0.500000           1.0
# 5  lr:0.0005 / num_fc:128    5       0.73         0.800000           0.8
# 6  lr:0.0005 / num_fc:128    6       0.59         0.555556           1.0
# 7  lr:0.0005 / num_fc:128    7       0.73         0.666667           0.8
# 8  lr:0.0005 / num_fc:128    8       0.57         0.625000           1.0
# 9  lr:0.0005 / num_fc:128    9       0.56         0.555556           1.0
#
#    Valid_F1  Test_AUC  Test_Precision  Test_Recall   Test_F1
# 0  0.714286  0.640000        0.562500          0.9  0.692308
# 1  0.769231  0.500000        0.600000          0.9  0.720000
# 2  0.736842  0.700000        0.625000          1.0  0.769231
# 3  0.692308  0.410000        0.500000          1.0  0.666667
# 4  0.666667  0.566667        0.473684          1.0  0.642857
# 5  0.800000  0.655556        0.529412          1.0  0.692308
# 6  0.714286  0.477778        0.473684          1.0  0.642857
# 7  0.727273  0.611111        0.642857          0.9  0.750000
# 8  0.769231  0.355556        0.526316          1.0  0.689655
# 9  0.714286  0.555556        0.555556          1.0  0.714286

# %%
result.to_csv(trainArgs['filename'], mode='w')
