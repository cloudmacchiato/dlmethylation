# %%
import os, torch
import numpy as np
import pandas as pd
from torch import nn
import torch.nn.functional as F
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %%
from dataPre import *
# Out:
# >> Pathway Data : KEGG
# pathway matrix shape :  torch.Size([184, 24669])
# num_pathway :  184
# >> Methylation Data: gene.average.beta.by.intensity.csv
# sample_dim :  455
# input_size (number of genes):  24669
# patient list :  ['GSM7057513', 'GSM7057514', 'GSM7057515', 'GSM7057516', 'GSM7057517', 'GSM7057518']
# feature list :  ['DDX11L1', 'LOC101928626', 'FAM87B', 'LINC01128', 'LOC643837', 'FAM41C']

# %%
trainArgs = {}
trainArgs['x_data'] = expression
trainArgs['y_data'] = status
trainArgs['pathway_info'] = pathway_info
# trainArgs['num_fc_list'] = [32, 64, 128]
# trainArgs['lr_list'] = [0.0001,0.0005,0.001]
trainArgs['num_fc_list'] = [128]
trainArgs['lr_list'] = [0.0005]
trainArgs['device'] = '0'
trainArgs['seed'] = 0
trainArgs['pathway'] = pathway
trainArgs['tissue'] = tissue
trainArgs['filename'] = '../../results/GOBP/result_mlp.csv'

# %%
from train import *
# Out:
# Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)

# %%
train = train_kfold_mlp(trainArgs)

# %%
result = train.kfold_mlp()
# Out:
# ****************************************************************************
# Fold 1 / 5
# ****************************************************************************
# Validation AUC increased (0.000000 --> 0.990476).  Saving model ...
# Validation AUC increased (0.990476 --> 0.995238).  Saving model ...
# Validation AUC increased (0.995238 --> 0.997619).  Saving model ...
# Validation AUC increased (0.997619 --> 1.000000).  Saving model ...
# ****************************************************************************
# Fold 2 / 5
# ****************************************************************************
# Validation AUC increased (0.000000 --> 0.964286).  Saving model ...
# Validation AUC increased (0.964286 --> 0.966667).  Saving model ...
# Validation AUC increased (0.966667 --> 0.980952).  Saving model ...
# Validation AUC increased (0.980952 --> 0.992857).  Saving model ...
# Validation AUC increased (0.992857 --> 0.995238).  Saving model ...
# Validation AUC increased (0.995238 --> 0.997619).  Saving model ...
# ****************************************************************************
# Fold 3 / 5
# ****************************************************************************
# Validation AUC increased (0.000000 --> 0.957143).  Saving model ...
# Validation AUC increased (0.957143 --> 0.957143).  Saving model ...
# Validation AUC increased (0.957143 --> 0.983333).  Saving model ...
# Validation AUC increased (0.983333 --> 0.988095).  Saving model ...
# Validation AUC increased (0.988095 --> 0.997619).  Saving model ...
# Validation AUC increased (0.997619 --> 1.000000).  Saving model ...
# ****************************************************************************
# Fold 4 / 5
# ****************************************************************************
# Validation AUC increased (0.000000 --> 0.983333).  Saving model ...
# Validation AUC increased (0.983333 --> 0.992857).  Saving model ...
# Validation AUC increased (0.992857 --> 0.997619).  Saving model ...
# Validation AUC increased (0.997619 --> 1.000000).  Saving model ...
# ****************************************************************************
# Fold 5 / 5
# ****************************************************************************
# Validation AUC increased (0.000000 --> 0.969048).  Saving model ...
# Validation AUC increased (0.969048 --> 0.971429).  Saving model ...
# Validation AUC increased (0.971429 --> 0.988095).  Saving model ...
# Validation AUC increased (0.988095 --> 0.992857).  Saving model ...
# Validation AUC increased (0.992857 --> 0.995238).  Saving model ...
# Validation AUC increased (0.995238 --> 1.000000).  Saving model ...

# %%
result
# Out:
#                hyperparam Fold  Valid_AUC  Valid_Precision  Valid_Recall  \
# 0  lr:0.0005 / num_fc:128    0   1.000000         1.000000           1.0
# 1  lr:0.0005 / num_fc:128    1   0.997619         0.952381           1.0
# 2  lr:0.0005 / num_fc:128    2   1.000000         1.000000           1.0
# 3  lr:0.0005 / num_fc:128    3   1.000000         1.000000           1.0
# 4  lr:0.0005 / num_fc:128    4   1.000000         1.000000           1.0
#
#    Valid_F1  Test_AUC  Test_Precision  Test_Recall   Test_F1  Test_PrAUC
# 0   1.00000  0.981141        0.975610     0.909091  0.941176    0.984033
# 1   0.97561  0.968599        1.000000     0.911111  0.953488    0.977317
# 2   1.00000  0.966667        0.893617     0.933333  0.913043    0.970054
# 3   1.00000  0.977778        0.934783     0.955556  0.945055    0.978650
# 4   1.00000  0.966184        0.974359     0.844444  0.904762    0.971749

# %%
result.to_csv('../../results/result_mlp.csv', mode='w')

# %%
trainArgs = {}
trainArgs['x_data'] = expression
trainArgs['y_data'] = status
trainArgs['pathway_info'] = pathway_info
# trainArgs['num_fc_list'] = [32, 64, 128]
# trainArgs['lr_list'] = [0.0001,0.0005,0.001]
trainArgs['num_fc_list'] = [128]
trainArgs['lr_list'] = [0.0005]
trainArgs['device'] = '0'
trainArgs['seed'] = 0
trainArgs['pathway'] = pathway
trainArgs['tissue'] = tissue
trainArgs['filename'] = '../../results/result3.csv'

# %%
train3 = train_kfold3(trainArgs)

# %%
result3 = train3.kfold()
# Out:
# ****************************************************************************
# Fold 1 / 10
# ****************************************************************************
# Validation AUC increased (0.000000 --> 0.867143).  Saving model ...
# Validation AUC increased (0.867143 --> 0.925714).  Saving model ...
# Validation AUC increased (0.925714 --> 0.942857).  Saving model ...
# Validation AUC increased (0.942857 --> 0.945714).  Saving model ...
# Validation AUC increased (0.945714 --> 0.952857).  Saving model ...
# Validation AUC increased (0.952857 --> 0.957143).  Saving model ...
# Validation AUC increased (0.957143 --> 0.958571).  Saving model ...
# Validation AUC increased (0.958571 --> 0.958571).  Saving model ...
# Validation AUC increased (0.958571 --> 0.960000).  Saving model ...
# Validation AUC increased (0.960000 --> 0.961429).  Saving model ...
# Validation AUC increased (0.961429 --> 0.962857).  Saving model ...
# Validation AUC increased (0.962857 --> 0.964286).  Saving model ...
# Validation AUC increased (0.964286 --> 0.965714).  Saving model ...
# Validation AUC increased (0.965714 --> 0.967143).  Saving model ...
# Validation AUC increased (0.967143 --> 0.968571).  Saving model ...
# Validation AUC increased (0.968571 --> 0.970000).  Saving model ...
# Validation AUC increased (0.970000 --> 0.971429).  Saving model ...
# Validation AUC increased (0.971429 --> 0.972857).  Saving model ...
# Validation AUC increased (0.972857 --> 0.974286).  Saving model ...
# Validation AUC increased (0.974286 --> 0.975714).  Saving model ...
# Validation AUC increased (0.975714 --> 0.977143).  Saving model ...
# Validation AUC increased (0.977143 --> 0.978571).  Saving model ...
# ****************************************************************************
# Fold 2 / 10
# ****************************************************************************
# Validation AUC increased (0.000000 --> 0.705714).  Saving model ...
# Validation AUC increased (0.705714 --> 0.802857).  Saving model ...
# Validation AUC increased (0.802857 --> 0.867143).  Saving model ...
# Validation AUC increased (0.867143 --> 0.892857).  Saving model ...
# Validation AUC increased (0.892857 --> 0.900000).  Saving model ...
# Validation AUC increased (0.900000 --> 0.921429).  Saving model ...
# Validation AUC increased (0.921429 --> 0.932857).  Saving model ...
# Validation AUC increased (0.932857 --> 0.935714).  Saving model ...
# Validation AUC increased (0.935714 --> 0.938571).  Saving model ...
# Validation AUC increased (0.938571 --> 0.942857).  Saving model ...
# Validation AUC increased (0.942857 --> 0.945714).  Saving model ...
# Validation AUC increased (0.945714 --> 0.950000).  Saving model ...
# Validation AUC increased (0.950000 --> 0.951429).  Saving model ...
# Validation AUC increased (0.951429 --> 0.952857).  Saving model ...
# Validation AUC increased (0.952857 --> 0.955714).  Saving model ...
# Validation AUC increased (0.955714 --> 0.958571).  Saving model ...
# Validation AUC increased (0.958571 --> 0.960000).  Saving model ...
# Validation AUC increased (0.960000 --> 0.962857).  Saving model ...
# Validation AUC increased (0.962857 --> 0.965714).  Saving model ...
# Validation AUC increased (0.965714 --> 0.965714).  Saving model ...
# Validation AUC increased (0.965714 --> 0.971429).  Saving model ...
# Validation AUC increased (0.971429 --> 0.972857).  Saving model ...
# Validation AUC increased (0.972857 --> 0.974286).  Saving model ...
# Validation AUC increased (0.974286 --> 0.975714).  Saving model ...
# Validation AUC increased (0.975714 --> 0.977143).  Saving model ...
# Validation AUC increased (0.977143 --> 0.978571).  Saving model ...
# Validation AUC increased (0.978571 --> 0.980000).  Saving model ...
# Validation AUC increased (0.980000 --> 0.981429).  Saving model ...
# Validation AUC increased (0.981429 --> 0.981429).  Saving model ...
# Validation AUC increased (0.981429 --> 0.982857).  Saving model ...
# ****************************************************************************
# Fold 3 / 10
# ****************************************************************************
# Validation AUC increased (0.000000 --> 0.850000).  Saving model ...
# Validation AUC increased (0.850000 --> 0.895714).  Saving model ...
# Validation AUC increased (0.895714 --> 0.918571).  Saving model ...
# Validation AUC increased (0.918571 --> 0.928571).  Saving model ...
# Validation AUC increased (0.928571 --> 0.932857).  Saving model ...
# Validation AUC increased (0.932857 --> 0.942857).  Saving model ...
# Validation AUC increased (0.942857 --> 0.947143).  Saving model ...
# Validation AUC increased (0.947143 --> 0.948571).  Saving model ...
# Validation AUC increased (0.948571 --> 0.950000).  Saving model ...
# Validation AUC increased (0.950000 --> 0.951429).  Saving model ...
# Validation AUC increased (0.951429 --> 0.952857).  Saving model ...
# Validation AUC increased (0.952857 --> 0.957143).  Saving model ...
# Validation AUC increased (0.957143 --> 0.958571).  Saving model ...
# Validation AUC increased (0.958571 --> 0.961429).  Saving model ...
# Validation AUC increased (0.961429 --> 0.962857).  Saving model ...
# Validation AUC increased (0.962857 --> 0.964286).  Saving model ...
# Validation AUC increased (0.964286 --> 0.965714).  Saving model ...
# Validation AUC increased (0.965714 --> 0.970000).  Saving model ...
# Validation AUC increased (0.970000 --> 0.971429).  Saving model ...
# Validation AUC increased (0.971429 --> 0.974286).  Saving model ...
# Validation AUC increased (0.974286 --> 0.975714).  Saving model ...
# Validation AUC increased (0.975714 --> 0.978571).  Saving model ...
# Validation AUC increased (0.978571 --> 0.980000).  Saving model ...
# ****************************************************************************
# Fold 4 / 10
# ****************************************************************************
# Validation AUC increased (0.000000 --> 0.787143).  Saving model ...
# Validation AUC increased (0.787143 --> 0.854286).  Saving model ...
# Validation AUC increased (0.854286 --> 0.871429).  Saving model ...
# Validation AUC increased (0.871429 --> 0.887143).  Saving model ...
# Validation AUC increased (0.887143 --> 0.891429).  Saving model ...
# Validation AUC increased (0.891429 --> 0.900000).  Saving model ...
# Validation AUC increased (0.900000 --> 0.905714).  Saving model ...
# Validation AUC increased (0.905714 --> 0.912857).  Saving model ...
# Validation AUC increased (0.912857 --> 0.915714).  Saving model ...
# Validation AUC increased (0.915714 --> 0.918571).  Saving model ...
# Validation AUC increased (0.918571 --> 0.921429).  Saving model ...
# Validation AUC increased (0.921429 --> 0.922857).  Saving model ...
# Validation AUC increased (0.922857 --> 0.924286).  Saving model ...
# Validation AUC increased (0.924286 --> 0.927143).  Saving model ...
# Validation AUC increased (0.927143 --> 0.927143).  Saving model ...
# Validation AUC increased (0.927143 --> 0.931429).  Saving model ...
# Validation AUC increased (0.931429 --> 0.934286).  Saving model ...
# Validation AUC increased (0.934286 --> 0.934286).  Saving model ...
# Validation AUC increased (0.934286 --> 0.935714).  Saving model ...
# Validation AUC increased (0.935714 --> 0.937143).  Saving model ...
# Validation AUC increased (0.937143 --> 0.940000).  Saving model ...
# Validation AUC increased (0.940000 --> 0.941429).  Saving model ...
# Validation AUC increased (0.941429 --> 0.944286).  Saving model ...
# Validation AUC increased (0.944286 --> 0.944286).  Saving model ...
# Validation AUC increased (0.944286 --> 0.945714).  Saving model ...
# Validation AUC increased (0.945714 --> 0.947143).  Saving model ...
# Validation AUC increased (0.947143 --> 0.948571).  Saving model ...
# Validation AUC increased (0.948571 --> 0.950000).  Saving model ...
# Validation AUC increased (0.950000 --> 0.951429).  Saving model ...
# Validation AUC increased (0.951429 --> 0.954286).  Saving model ...
# Validation AUC increased (0.954286 --> 0.955714).  Saving model ...
# Validation AUC increased (0.955714 --> 0.957143).  Saving model ...
# Validation AUC increased (0.957143 --> 0.958571).  Saving model ...
# Validation AUC increased (0.958571 --> 0.960000).  Saving model ...
# ****************************************************************************
# Fold 5 / 10
# ****************************************************************************
# Validation AUC increased (0.000000 --> 0.771429).  Saving model ...
# Validation AUC increased (0.771429 --> 0.850000).  Saving model ...
# Validation AUC increased (0.850000 --> 0.907143).  Saving model ...
# Validation AUC increased (0.907143 --> 0.922857).  Saving model ...
# Validation AUC increased (0.922857 --> 0.932857).  Saving model ...
# Validation AUC increased (0.932857 --> 0.935714).  Saving model ...
# Validation AUC increased (0.935714 --> 0.937143).  Saving model ...
# Validation AUC increased (0.937143 --> 0.940000).  Saving model ...
# Validation AUC increased (0.940000 --> 0.941429).  Saving model ...
# Validation AUC increased (0.941429 --> 0.942857).  Saving model ...
# Validation AUC increased (0.942857 --> 0.944286).  Saving model ...
# Validation AUC increased (0.944286 --> 0.945714).  Saving model ...
# Validation AUC increased (0.945714 --> 0.947143).  Saving model ...
# Validation AUC increased (0.947143 --> 0.951429).  Saving model ...
# Validation AUC increased (0.951429 --> 0.952857).  Saving model ...
# Validation AUC increased (0.952857 --> 0.952857).  Saving model ...
# Validation AUC increased (0.952857 --> 0.954286).  Saving model ...
# Validation AUC increased (0.954286 --> 0.957143).  Saving model ...
# Validation AUC increased (0.957143 --> 0.960000).  Saving model ...
# Validation AUC increased (0.960000 --> 0.960000).  Saving model ...
# Validation AUC increased (0.960000 --> 0.961429).  Saving model ...
# Validation AUC increased (0.961429 --> 0.965714).  Saving model ...
# ****************************************************************************
# Fold 6 / 10
# ****************************************************************************
# Validation AUC increased (0.000000 --> 0.824286).  Saving model ...
# Validation AUC increased (0.824286 --> 0.905714).  Saving model ...
# Validation AUC increased (0.905714 --> 0.922857).  Saving model ...
# Validation AUC increased (0.922857 --> 0.930000).  Saving model ...
# Validation AUC increased (0.930000 --> 0.940000).  Saving model ...
# Validation AUC increased (0.940000 --> 0.948571).  Saving model ...
# Validation AUC increased (0.948571 --> 0.950000).  Saving model ...
# Validation AUC increased (0.950000 --> 0.951429).  Saving model ...
# Validation AUC increased (0.951429 --> 0.952857).  Saving model ...
# Validation AUC increased (0.952857 --> 0.954286).  Saving model ...
# Validation AUC increased (0.954286 --> 0.957143).  Saving model ...
# Validation AUC increased (0.957143 --> 0.958571).  Saving model ...
# Validation AUC increased (0.958571 --> 0.960000).  Saving model ...
# Validation AUC increased (0.960000 --> 0.961429).  Saving model ...
# Validation AUC increased (0.961429 --> 0.965714).  Saving model ...
# Validation AUC increased (0.965714 --> 0.972857).  Saving model ...
# Validation AUC increased (0.972857 --> 0.975714).  Saving model ...
# Validation AUC increased (0.975714 --> 0.982857).  Saving model ...
# Validation AUC increased (0.982857 --> 0.985714).  Saving model ...
# Validation AUC increased (0.985714 --> 0.987143).  Saving model ...
# ****************************************************************************
# Fold 7 / 10
# ****************************************************************************
# Validation AUC increased (0.000000 --> 0.777143).  Saving model ...
# Validation AUC increased (0.777143 --> 0.827143).  Saving model ...
# Validation AUC increased (0.827143 --> 0.835714).  Saving model ...
# Validation AUC increased (0.835714 --> 0.851429).  Saving model ...
# Validation AUC increased (0.851429 --> 0.875714).  Saving model ...
# Validation AUC increased (0.875714 --> 0.885714).  Saving model ...
# Validation AUC increased (0.885714 --> 0.897143).  Saving model ...
# Validation AUC increased (0.897143 --> 0.902857).  Saving model ...
# Validation AUC increased (0.902857 --> 0.907143).  Saving model ...
# Validation AUC increased (0.907143 --> 0.908571).  Saving model ...
# Validation AUC increased (0.908571 --> 0.915714).  Saving model ...
# Validation AUC increased (0.915714 --> 0.918571).  Saving model ...
# Validation AUC increased (0.918571 --> 0.921429).  Saving model ...
# Validation AUC increased (0.921429 --> 0.922857).  Saving model ...
# Validation AUC increased (0.922857 --> 0.924286).  Saving model ...
# Validation AUC increased (0.924286 --> 0.925714).  Saving model ...
# Validation AUC increased (0.925714 --> 0.927143).  Saving model ...
# Validation AUC increased (0.927143 --> 0.928571).  Saving model ...
# Validation AUC increased (0.928571 --> 0.935714).  Saving model ...
# Validation AUC increased (0.935714 --> 0.938571).  Saving model ...
# Validation AUC increased (0.938571 --> 0.940000).  Saving model ...
# Validation AUC increased (0.940000 --> 0.941429).  Saving model ...
# Validation AUC increased (0.941429 --> 0.944286).  Saving model ...
# Validation AUC increased (0.944286 --> 0.947143).  Saving model ...
# Validation AUC increased (0.947143 --> 0.948571).  Saving model ...
# Validation AUC increased (0.948571 --> 0.951429).  Saving model ...
# Validation AUC increased (0.951429 --> 0.957143).  Saving model ...
# Validation AUC increased (0.957143 --> 0.960000).  Saving model ...
# Validation AUC increased (0.960000 --> 0.961429).  Saving model ...
# Validation AUC increased (0.961429 --> 0.964286).  Saving model ...
# Validation AUC increased (0.964286 --> 0.965714).  Saving model ...
# Validation AUC increased (0.965714 --> 0.967143).  Saving model ...
# Validation AUC increased (0.967143 --> 0.968571).  Saving model ...
# Validation AUC increased (0.968571 --> 0.970000).  Saving model ...
# Validation AUC increased (0.970000 --> 0.975714).  Saving model ...
# Validation AUC increased (0.975714 --> 0.978571).  Saving model ...
# Validation AUC increased (0.978571 --> 0.985714).  Saving model ...
# ****************************************************************************
# Fold 8 / 10
# ****************************************************************************
# Validation AUC increased (0.000000 --> 0.892857).  Saving model ...
# Validation AUC increased (0.892857 --> 0.914286).  Saving model ...
# Validation AUC increased (0.914286 --> 0.927143).  Saving model ...
# Validation AUC increased (0.927143 --> 0.935714).  Saving model ...
# Validation AUC increased (0.935714 --> 0.938571).  Saving model ...
# Validation AUC increased (0.938571 --> 0.941429).  Saving model ...
# Validation AUC increased (0.941429 --> 0.942857).  Saving model ...
# Validation AUC increased (0.942857 --> 0.944286).  Saving model ...
# Validation AUC increased (0.944286 --> 0.950000).  Saving model ...
# Validation AUC increased (0.950000 --> 0.951429).  Saving model ...
# Validation AUC increased (0.951429 --> 0.954286).  Saving model ...
# Validation AUC increased (0.954286 --> 0.955714).  Saving model ...
# Validation AUC increased (0.955714 --> 0.958571).  Saving model ...
# Validation AUC increased (0.958571 --> 0.960000).  Saving model ...
# Validation AUC increased (0.960000 --> 0.961429).  Saving model ...
# Validation AUC increased (0.961429 --> 0.962857).  Saving model ...
# Validation AUC increased (0.962857 --> 0.965714).  Saving model ...
# Validation AUC increased (0.965714 --> 0.967143).  Saving model ...
# Validation AUC increased (0.967143 --> 0.968571).  Saving model ...
# Validation AUC increased (0.968571 --> 0.971429).  Saving model ...
# Validation AUC increased (0.971429 --> 0.972857).  Saving model ...
# Validation AUC increased (0.972857 --> 0.974286).  Saving model ...
# Validation AUC increased (0.974286 --> 0.975714).  Saving model ...
# Validation AUC increased (0.975714 --> 0.977143).  Saving model ...
# Validation AUC increased (0.977143 --> 0.980000).  Saving model ...
# Validation AUC increased (0.980000 --> 0.981429).  Saving model ...
# Validation AUC increased (0.981429 --> 0.982857).  Saving model ...
# Validation AUC increased (0.982857 --> 0.984286).  Saving model ...
# Validation AUC increased (0.984286 --> 0.988571).  Saving model ...
# Validation AUC increased (0.988571 --> 0.990000).  Saving model ...
# Validation AUC increased (0.990000 --> 0.991429).  Saving model ...
# Validation AUC increased (0.991429 --> 0.992857).  Saving model ...
# Validation AUC increased (0.992857 --> 0.994286).  Saving model ...
# Validation AUC increased (0.994286 --> 0.994286).  Saving model ...
# Validation AUC increased (0.994286 --> 0.995714).  Saving model ...
# ****************************************************************************
# Fold 9 / 10
# ****************************************************************************
# Validation AUC increased (0.000000 --> 0.617143).  Saving model ...
# Validation AUC increased (0.617143 --> 0.712857).  Saving model ...
# Validation AUC increased (0.712857 --> 0.765714).  Saving model ...
# Validation AUC increased (0.765714 --> 0.804286).  Saving model ...
# Validation AUC increased (0.804286 --> 0.824286).  Saving model ...
# Validation AUC increased (0.824286 --> 0.831429).  Saving model ...
# Validation AUC increased (0.831429 --> 0.835714).  Saving model ...
# Validation AUC increased (0.835714 --> 0.837143).  Saving model ...
# Validation AUC increased (0.837143 --> 0.838571).  Saving model ...
# Validation AUC increased (0.838571 --> 0.844286).  Saving model ...
# Validation AUC increased (0.844286 --> 0.848571).  Saving model ...
# Validation AUC increased (0.848571 --> 0.851429).  Saving model ...
# Validation AUC increased (0.851429 --> 0.854286).  Saving model ...
# Validation AUC increased (0.854286 --> 0.861429).  Saving model ...
# Validation AUC increased (0.861429 --> 0.867143).  Saving model ...
# Validation AUC increased (0.867143 --> 0.868571).  Saving model ...
# Validation AUC increased (0.868571 --> 0.871429).  Saving model ...
# Validation AUC increased (0.871429 --> 0.872857).  Saving model ...
# Validation AUC increased (0.872857 --> 0.875714).  Saving model ...
# Validation AUC increased (0.875714 --> 0.877143).  Saving model ...
# Validation AUC increased (0.877143 --> 0.877143).  Saving model ...
# Validation AUC increased (0.877143 --> 0.878571).  Saving model ...
# Validation AUC increased (0.878571 --> 0.880000).  Saving model ...
# Validation AUC increased (0.880000 --> 0.881429).  Saving model ...
# Validation AUC increased (0.881429 --> 0.885714).  Saving model ...
# Validation AUC increased (0.885714 --> 0.887143).  Saving model ...
# Validation AUC increased (0.887143 --> 0.888571).  Saving model ...
# Validation AUC increased (0.888571 --> 0.891429).  Saving model ...
# Validation AUC increased (0.891429 --> 0.892857).  Saving model ...
# Validation AUC increased (0.892857 --> 0.894286).  Saving model ...
# Validation AUC increased (0.894286 --> 0.897143).  Saving model ...
# Validation AUC increased (0.897143 --> 0.898571).  Saving model ...
# Validation AUC increased (0.898571 --> 0.901429).  Saving model ...
# Validation AUC increased (0.901429 --> 0.904286).  Saving model ...
# Validation AUC increased (0.904286 --> 0.905714).  Saving model ...
# Validation AUC increased (0.905714 --> 0.907143).  Saving model ...
# Validation AUC increased (0.907143 --> 0.910000).  Saving model ...
# Validation AUC increased (0.910000 --> 0.912857).  Saving model ...
# ****************************************************************************
# Fold 10 / 10
# ****************************************************************************
# Validation AUC increased (0.000000 --> 0.942857).  Saving model ...
# Validation AUC increased (0.942857 --> 0.955714).  Saving model ...
# Validation AUC increased (0.955714 --> 0.961429).  Saving model ...
# Validation AUC increased (0.961429 --> 0.977143).  Saving model ...
# Validation AUC increased (0.977143 --> 0.984286).  Saving model ...
# Validation AUC increased (0.984286 --> 0.985714).  Saving model ...
# Validation AUC increased (0.985714 --> 0.987143).  Saving model ...
# Validation AUC increased (0.987143 --> 0.988571).  Saving model ...
# Validation AUC increased (0.988571 --> 0.990000).  Saving model ...
# Validation AUC increased (0.990000 --> 0.992857).  Saving model ...
# Validation AUC increased (0.992857 --> 0.994286).  Saving model ...
# Validation AUC increased (0.994286 --> 0.995714).  Saving model ...
# Validation AUC increased (0.995714 --> 0.998571).  Saving model ...

# %%
result3
# Out:
#               hyperparam Fold  Valid_AUC  Valid_Precision  Valid_Recall  \
# 0  lr:0.0001 / num_fc:32    0   0.978571         1.000000      0.971429
# 1  lr:0.0001 / num_fc:32    1   0.982857         1.000000      0.914286
# 2  lr:0.0001 / num_fc:32    2   0.980000         0.918919      0.971429
# 3  lr:0.0001 / num_fc:32    3   0.960000         0.944444      0.971429
# 4  lr:0.0001 / num_fc:32    4   0.965714         0.941176      0.914286
# 5  lr:0.0001 / num_fc:32    5   0.987143         0.944444      0.971429
# 6  lr:0.0001 / num_fc:32    6   0.985714         0.897436      1.000000
# 7  lr:0.0001 / num_fc:32    7   0.995714         0.972222      1.000000
# 8  lr:0.0001 / num_fc:32    8   0.912857         0.914286      0.914286
# 9  lr:0.0001 / num_fc:32    9   0.998571         0.972222      1.000000
#
#    Valid_F1  Test_AUC  Test_Precision  Test_Recall   Test_F1
# 0  0.985507  0.978992        0.894737     1.000000  0.944444
# 1  0.955224  0.970588        0.916667     0.970588  0.942857
# 2  0.944444  0.987143        0.945946     1.000000  0.972222
# 3  0.957746  0.928571        0.846154     0.942857  0.891892
# 4  0.927536  0.928571        0.897436     1.000000  0.945946
# 5  0.957746  1.000000        1.000000     1.000000  1.000000
# 6  0.945946  0.992857        0.945946     1.000000  0.972222
# 7  0.985915  0.916176        0.914286     0.941176  0.927536
# 8  0.914286  0.942647        0.914286     0.941176  0.927536
# 9  0.985915  0.938235        0.916667     0.970588  0.942857

# %%
result3.to_csv("../../results/result3.csv", mode='w')

# %%
trainArgs['filename']
# Out:
# 'result.csv'
